# %% [markdown]
# <a href="https://colab.research.google.com/github/theiaa7/PythonLC/blob/main/%231_data_upload_%26_read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Inisiasi Library

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# dataset upload manual script

# %%
from google.colab import files
dataset = files.upload()
# Out:
#      <input type="file" id="files-0d94b305-bfbf-44d2-8272-86626df4bbd3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d94b305-bfbf-44d2-8272-86626df4bbd3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# setting keys untuk framing

# %%
dataset = pd.read_csv('Data.csv')
dataset.keys()
# Out:
# Index(['Cause', 'Type', 'Year', 'Data Redundancy', ' Total ', ' Source ',
#        ' Page at Source ', ' Source URL '],
#       dtype='object')

# %% [markdown]
# bikin dataframe dan konversi ke array

# %%
data = pd.DataFrame(dataset)
data
# Out:
#                          Cause                           Type  Year  \
# 0              Abrasi Air Laut                   Bencana Alam  2012
# 1                         AIDS  Bencana Non Alam dan Penyakit  2000
# 2                         AIDS  Bencana Non Alam dan Penyakit  2001
# 3                         AIDS  Bencana Non Alam dan Penyakit  2002
# 4                         AIDS  Bencana Non Alam dan Penyakit  2003
# ..                         ...                            ...   ...
# 611          Tuberkulosis paru  Bencana Non Alam dan Penyakit  2004
# 612  Tuberkulosis paru lainnya  Bencana Non Alam dan Penyakit  2005
# 613   Wabah Penyakit (Epidemi)  Bencana Non Alam dan Penyakit  2016
# 614   Wabah Penyakit (Epidemi)  Bencana Non Alam dan Penyakit  2017
# 615   Wabah Penyakit (Epidemi)  Bencana Non Alam dan Penyakit  2019
#
#      Data Redundancy   Total                                   Source   \
# 0                  1     -      Profil Kesehatan Indonesia Tahun 2012
# ...

# %%
X = np.asarray(dataset)
print(X)
# Out:
# [['Abrasi Air Laut' 'Bencana Alam' 2012 ...
#   ' Profil Kesehatan Indonesia Tahun 2012 ' 'Lampiran 3.38'
#   'https://pusdatin.kemkes.go.id/download.php?file=download/pusdatin/profil-kesehatan-indonesia/profil-kesehatan-indonesia-2012.pdf']
#  ['AIDS' 'Bencana Non Alam dan Penyakit' 2000 ...
#   ' Profil Kesehatan Indonesia Tahun 2004 ' '78'
#   'https://pusdatin.kemkes.go.id/download.php?file=download/pusdatin/profil-kesehatan-indonesia/profil-kesehatan-indonesia-2004.pdf']
#  ['AIDS' 'Bencana Non Alam dan Penyakit' 2001 ...
#   ' Profil Kesehatan Indonesia Tahun 2004 ' '78'
#   'https://pusdatin.kemkes.go.id/download.php?file=download/pusdatin/profil-kesehatan-indonesia/profil-kesehatan-indonesia-2004.pdf']
#  ...
#  ['Wabah Penyakit (Epidemi)' 'Bencana Non Alam dan Penyakit' 2016 ...
#   ' Profil Kesehatan Indonesia Tahun 2016 ' 'Lampiran 6.37'
#   'https://pusdatin.kemkes.go.id/download.php?file=download/pusdatin/profil-kesehatan-indonesia/Profil-Kesehatan-Indonesia-2016.pdf']
# ...
